# %% [markdown]
# # 🚢 MarSlick (SIH 26143) — Google Colab Backend Host
# This notebook runs the **MarSlick Python/Django + PyTorch** backend on Google Colab's free 12 GB RAM / GPU infrastructure and exposes it to the internet via Cloudflare Tunnel.
#
# No credit card or paid subscriptions required.

# %%
# Step 1: Clone the repository (if not already present)
import os
if not os.path.exists("prototype_evinco"):
    # !git clone https://github.com/Aral-549/prototype_evinco.git
    # %cd prototype_evinco
else:
    # %cd prototype_evinco
    # !git pull

# %%
# Step 2: Run the automated backend server & Cloudflare Tunnel
# !python colab_runner.py
